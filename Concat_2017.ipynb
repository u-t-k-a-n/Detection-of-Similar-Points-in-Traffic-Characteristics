# %% [markdown]
# <a href="https://colab.research.google.com/github/u-t-k-a-n/Detection-of-Similar-Points-in-Traffic-Characteristics/blob/main/Concat_2017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
import os
path = "drive/MyDrive/2017_v1"
files = list()
for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        files.append(os.path.join(dirname, filename))
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(files[0],index_col=["time"])

# %%
df.drop(columns=["is_under_10","is_over_130"],inplace=True)

# %%
df = df.rename(columns={"speed":files[0]})

# %%
df
# Out:
#                      drive/MyDrive/2017_v1/739_1_2017.csv
# time
# 2017-01-01 00:00:00                             77.000000
# 2017-01-01 00:05:00                             57.000000
# 2017-01-01 00:10:00                             57.000000
# 2017-01-01 00:15:00                             57.295069
# 2017-01-01 00:20:00                             57.000000
# ...                                                   ...
# 2017-12-31 23:35:00                             10.000000
# 2017-12-31 23:40:00                             10.000000
# 2017-12-31 23:45:00                             10.000000
# 2017-12-31 23:50:00                             10.000000
# 2017-12-31 23:55:00                             10.000000
#
# [105120 rows x 1 columns]

# %%
for i in range(1,len(files)):
  df2 = pd.read_csv(files[i],index_col=["time"])
  df2.drop(columns=["is_under_10","is_over_130"],inplace=True)
  df2 = df2.rename(columns={"speed":files[i]})
  df = pd.concat([df,df2],axis=1)

# %%
df
# Out:
#                      drive/MyDrive/2017_v1/739_1_2017.csv  ...  drive/MyDrive/2017_v1/714_1_2017.csv
# time                                                       ...
# 2017-01-01 00:00:00                             77.000000  ...                            112.000000
# 2017-01-01 00:05:00                             57.000000  ...                            108.000000
# 2017-01-01 00:10:00                             57.000000  ...                            108.000000
# 2017-01-01 00:15:00                             57.295069  ...                            108.059014
# 2017-01-01 00:20:00                             57.000000  ...                            108.000000
# ...                                                   ...  ...                                   ...
# 2017-12-31 23:35:00                             10.000000  ...                             10.000000
# 2017-12-31 23:40:00                             10.000000  ...                             10.000000
# ...

# %%
df.to_csv("drive/MyDrive/2017_concat/Concat_2017.csv")

# %%
df = pd.read_csv("drive/MyDrive/2017_concat/Concat_2017.csv")

# %%
df_corr = df.corr()

# %%
df_corr
# Out:
#                                        drive/MyDrive/2017_v1/739_1_2017.csv  ...  drive/MyDrive/2017_v1/714_1_2017.csv
# drive/MyDrive/2017_v1/739_1_2017.csv                               1.000000  ...                             -0.078712
# drive/MyDrive/2017_v1/482_1_2017.csv                               0.369211  ...                              0.069958
# drive/MyDrive/2017_v1/1920_1_2017.csv                             -0.022437  ...                              0.447315
# drive/MyDrive/2017_v1/715_0_2017.csv                               0.161186  ...                              0.251368
# drive/MyDrive/2017_v1/1778_0_2017.csv                              0.551243  ...                              0.077545
# ...                                                                     ...  ...                                   ...
# drive/MyDrive/2017_v1/189_0_2017.csv                               0.585353  ...                              0.200337
# ...
