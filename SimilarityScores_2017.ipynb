# %% [markdown]
# <a href="https://colab.research.google.com/github/u-t-k-a-n/Detection-of-Similar-Points-in-Traffic-Characteristics/blob/main/SimilarityScores_2017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path1 = "drive/MyDrive/SimilarityScores/2017/0.csv"
df1 = pd.read_csv(path1)

# %%
df1
# Out:
#                               Unnamed: 0  ...  drive/MyDrive/2017_v1/714_1_2017.csv
# 0   drive/MyDrive/2017_v1/739_1_2017.csv  ...                             -0.078712
# 1   drive/MyDrive/2017_v1/482_1_2017.csv  ...                              0.069958
# 2  drive/MyDrive/2017_v1/1920_1_2017.csv  ...                              0.447315
# 3   drive/MyDrive/2017_v1/715_0_2017.csv  ...                              0.251368
# 4  drive/MyDrive/2017_v1/1778_0_2017.csv  ...                              0.077545
# 5   drive/MyDrive/2017_v1/722_1_2017.csv  ...                              0.203947
# 6   drive/MyDrive/2017_v1/306_1_2017.csv  ...                              0.294495
# 7  drive/MyDrive/2017_v1/1832_1_2017.csv  ...                              0.268254
# 8  drive/MyDrive/2017_v1/1923_1_2017.csv  ...                              0.458536
# 9   drive/MyDrive/2017_v1/603_1_2017.csv  ...                              0.093433
#
# [10 rows x 1467 columns]

# %%
for i in range(1,147):
  path2 = "drive/MyDrive/SimilarityScores/2017/{}.csv".format(i)
  tmp = pd.read_csv(path2)
  for j in range(len(tmp)):
    df1.loc[i*10+j] = tmp.iloc[j]

# %%
df1
# Out:
#                                  Unnamed: 0  ...  drive/MyDrive/2017_v1/714_1_2017.csv
# 0      drive/MyDrive/2017_v1/739_1_2017.csv  ...                             -0.078712
# 1      drive/MyDrive/2017_v1/482_1_2017.csv  ...                              0.069958
# 2     drive/MyDrive/2017_v1/1920_1_2017.csv  ...                              0.447315
# 3      drive/MyDrive/2017_v1/715_0_2017.csv  ...                              0.251368
# 4     drive/MyDrive/2017_v1/1778_0_2017.csv  ...                              0.077545
# ...                                     ...  ...                                   ...
# 1461   drive/MyDrive/2017_v1/189_0_2017.csv  ...                              0.200337
# 1462  drive/MyDrive/2017_v1/1751_0_2017.csv  ...                              0.307503
# 1463   drive/MyDrive/2017_v1/641_1_2017.csv  ...                              0.334742
# 1464   drive/MyDrive/2017_v1/542_1_2017.csv  ...                              0.122937
# ...

# %%
df1.to_csv("drive/MyDrive/SimilarityScores/2017/SimilarityScores_2017_v2.csv")

# %%
path1 = "drive/MyDrive/SimilarityScores/2017/SimilarityScores_2017_v2.csv"

# %%
df1 = pd.read_csv(path1)

# %%
df1
# Out:
#       Unnamed: 0  ... drive/MyDrive/2017_v1/714_1_2017.csv
# 0              0  ...                            -0.078712
# 1              1  ...                             0.069958
# 2              2  ...                             0.447315
# 3              3  ...                             0.251368
# 4              4  ...                             0.077545
# ...          ...  ...                                  ...
# 1461        1461  ...                             0.200337
# 1462        1462  ...                             0.307503
# 1463        1463  ...                             0.334742
# 1464        1464  ...                             0.122937
# 1465        1465  ...                             1.000000
#
# [1466 rows x 1468 columns]
